# %% [markdown]
# # Text Analysis dashboard
#
# Because Power BI dashboards can only be viewed interactively with a Power BI license, I have decided to include static screenshots of one of the dashboards I have created here.
#
# This dashboard was created using data from a project I completed in Python. The data is a set of text messages sent between two individuals. ([Link to project](https://github.com/eviee3008/Text_Message_Analysis))

# %% [markdown]
# ![Screenshot 2023-10-11 112754.png](<attachment:Screenshot 2023-10-11 112754.png>)

# %% [markdown]
# ![Screenshot 2023-10-11 112941.png](<attachment:Screenshot 2023-10-11 112941.png>)

# %% [markdown]
# ![Screenshot 2023-10-11 113014.png](<attachment:Screenshot 2023-10-11 113014.png>)

# %% [markdown]
# ![Screenshot 2023-10-11 113103.png](<attachment:Screenshot 2023-10-11 113103.png>)

# %% [markdown]
# ![Screenshot 2023-10-11 113103.png](<attachment:Screenshot 2023-10-11 113103.png>)

# %% [markdown]
# ![Screenshot 2023-10-11 113232.png](<attachment:Screenshot 2023-10-11 113232.png>)
