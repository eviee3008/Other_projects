# %% [markdown]
# # Sports Team dashboard
#
# Because Power BI dashboards can only be viewed interactively with a Power BI license, I have decided to include static screenshots of one of the dashboards I have created here.
#
# This dashboard was created using data from an assignment I completed as part of a Data Science online course. The data is the wins vs. losses of American sports teams in 2018.([Link to assignment notebook](https://github.com/eviee3008/Python_Data_Science/blob/main/Assignment4.ipynb))

# %% [markdown]
# ![Screenshot 2023-10-08 224343.png](<attachment:Screenshot 2023-10-08 224343.png>)

# %% [markdown]
# ![Screenshot 2023-10-08 230342.png](<attachment:Screenshot 2023-10-08 230342.png>)

# %% [markdown]
# ![Screenshot 2023-10-08 230459.png](<attachment:Screenshot 2023-10-08 230459.png>)

# %% [markdown]
# ![Screenshot 2023-10-08 230633.png](<attachment:Screenshot 2023-10-08 230633.png>)
